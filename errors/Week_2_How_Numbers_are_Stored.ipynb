# %% [markdown]
# <a href="https://colab.research.google.com/github/mdaugherity/Numerical2024/blob/main/errors/Week_2_How_Numbers_are_Stored.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PHYS 351 - Applied Numerical
# Fall 2022, Dr. Daugherity
#
# Examples for how computers store numbers.  The moral for today:
#
# **COMPUTERS STORE APPROXIMATE VALUES, NOT EQUATIONS!**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Warm-up
# Make this plot

# %%
x = np.linspace(0,10,20)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x,y1,'b-s',label='Sin')
plt.plot(x,y2,'g:o',label='Cos')

plt.title('Sin and Cos')
plt.xlabel('x [m]')
plt.ylabel('y [in]')
plt.grid()

plt.legend()
plt.show()

# %% [markdown]
# # The Problem
# Math is not exact in a computer!  Why?  Because the computer can only store 64-bit approximations of numbers

# %%
2.6 + 0.6
# Out:
# 3.2

# %%
2.6 + 0.2 + 0.2 + 0.2
# Out:
# 3.2000000000000006

# %%
(2)**0.5
# Out:
# 1.4142135623730951

# %%
(2)**0.5 * (2)**0.5
# Out:
# 2.0000000000000004

# %%
(2)**0.5 * (2)**0.5 - 2
# Out:
# 4.440892098500626e-16

# %% [markdown]
# # Representation
# You need to be comfortable with binary (base 2) and hex (base 16).  Python can help.

# %%
bin(26)
# Out:
# '0b11010'

# %%
0b11010
# Out:
# 26

# %%
0b0010101011001011010101010110101011010
# Out:
# 22974999898

# %%
4*256+11*16+7
# Out:
# 1207

# %%
0x4B7
# Out:
# 1207

# %%
bin(1207)
# Out:
# '0b10010110111'

# %%
bin(1207)
# Out:
# '0b10010110111'

# %%
2**1023
# Out:
# 

# %%
2**-1023
# Out:
# 1.1125369292536007e-308

# %%
float.hex(26.0)
# Out:
# '0x1.a000000000000p+4'

# %%
print( float.hex((2**0.5)  * (2**0.5)) )
print( float.hex(2.0) )
# Out:
# 0x1.0000000000001p+1
# 0x1.0000000000000p+1

# %% [markdown]
# **PRACTICE:** what is 0xCAFE in base-10?

# %%
#0xCAFE

# %% [markdown]
# # Machine Epsilon
# Find the **largest** possible number that we can add to 1 and not change any bits:
# $1 + ϵ = 1$

# %%
1 + 1e-16
# Out:
# 1.0

# %%
print( float.hex(1.0))
print( float.hex(1.0 + 1e-10))
print( float.hex(1.0 + 1e-15))
print( float.hex(1.0 + 1e-16))
# Out:
# 0x1.0000000000000p+0
# 0x1.000000006df38p+0
# 0x1.0000000000005p+0
# 0x1.0000000000000p+0

# %%
np.finfo(float).eps
# Out:
# 2.220446049250313e-16

# %%
np.finfo(float)
# Out:
# finfo(resolution=1e-15, min=-1.7976931348623157e+308, max=1.7976931348623157e+308, dtype=float64)

# %% [markdown]
# # Equality
# WARNING!  Danger lies below.

# %%
x = 3.2
y = 2.6 + 0.2 + 0.2 + 0.2
if(x==y):
  print("equal")
else:
  print("nope")
# Out:
# nope

# %%
x = 2
y = (2)**0.5 * (2)**0.5
print(x==y)
# Out:
# False

# %% [markdown]
# BE VERY CAREFUL in checking if two floating-point numbers are equal!
#
# **NEVER** just check for x==y, instead check that they are close enough

# %%
x==y
# Out:
# False

# %%
np.abs(x-y)<1e-12
# Out:
# True

# %%
np.allclose(x,y)
# Out:
# True

# %% [markdown]
# Reference: https://numpy.org/doc/stable/reference/generated/numpy.allclose.html
#
# You can specify a tolerance about how close is *close enough*.  Default absolute tolerance is 1e-8

# %% [markdown]
# # Sumup vs Sumdown
# A nefarious example

# %%
# Sum up vs sum down
N = 1000
sumup = 0
for i in range(1,N):   # make sure to skip zero!
  sumup+=1/i

sumdown = 0
for i in range(N-1,0,-1):  # counts down from N-1 to 1
  sumdown +=1/i

print(sumup)
print(sumdown)
print(sumup-sumdown)
# Out:
# 7.484470860550343
# 7.484470860550341
# 1.7763568394002505e-15

# %% [markdown]
# Plot version 1

# %%
NLIST = [1000, 10000, 100000, 1000000]
NUM = len(NLIST)

ups = np.zeros(NUM)
downs = np.zeros(NUM)

for i in range(NUM):
  N = NLIST[i]
  print(N)
  sumup = 0
  for j in range(1,N):   # make sure to skip zero!
    sumup+=1/j
  ups[i] = sumup

  sumdown = 0
  for j in range(N-1,0,-1):  # counts down from N-1 to 1
    sumdown +=1/j
  downs[i] = sumdown

diff = np.abs(ups - downs)

plt.loglog(NLIST, diff,'ko-')
plt.xlabel('N')
plt.ylabel(' |up-down|')
plt.show()
# Out:
# 1000
# 10000
# 100000
# 1000000

# %% [markdown]
# Plot version 2

# %%
NLIST = np.logspace(3,7,5)
NUM = len(NLIST)

ups = np.zeros(NUM)
downs = np.zeros(NUM)

for i in range(NUM):
  N = int(NLIST[i])
  #print(N)
  sumup = 0
  for j in range(1,N):   # make sure to skip zero!
    sumup+=1/j
  ups[i] = sumup

  sumdown = 0
  for j in range(N-1,0,-1):  # counts down from N-1 to 1
    sumdown +=1/j
  downs[i] = sumdown

diff = np.abs(ups - downs)

plt.loglog(NLIST, diff,'ko-')
plt.xlabel('N')
plt.ylabel(' |up-down|')
plt.show()
